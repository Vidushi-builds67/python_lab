# %% [markdown]
# <a href="https://colab.research.google.com/github/Vidushi-builds67/python_lab/blob/main/LEARNING_FUNCTIONS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def remove_last(lst):
  lst.pop()
my_list=[10,20,30,40]
print ("before function calling", my_list)
remove_last(my_list)
print ("before function calling", my_list)
# Out:
# before function calling [10, 20, 30, 40]
# before function calling [10, 20, 30]

# %%
def change_string(s):
  s="X"+s[1:]
  print ("inside function:",s)
my_string="HELLO"
print ("before function calling", my_string)
change_string(my_string)
print ("after function calling", my_string)
# Out:
# before function calling HELLO
# inside function: XELLO
# after function calling HELLO

# %%
def add_entry(d):
 d['city']="DELHI"
my_dict={"name":"mica", "age":"18"}
print ("before function calling", my_dict)
add_entry(my_dict)
print ("after function calling", my_dict)
# Out:
# before function calling {'name': 'mica', 'age': '18'}
# after function calling {'name': 'mica', 'age': '18', 'city': 'DELHI'}

# %%
def reassign_dict(d):
  my_dict={"name":"mica", "age":"18"}
print("before rebinding", my_dict)
reassign_dict(my_dict)
print ("after rebinding", my_dict)
# Out:
# before rebinding {'name': 'mica', 'age': '18', 'city': 'DELHI'}
# after rebinding {'name': 'mica', 'age': '18', 'city': 'DELHI'}

# %%
def max(a,b):
  if a>b:
    return a
  else:
    return b
num1=float(input("enter first number:"))
num2=float(input("enter second number:"))
result=max(num1,num2)
print("greater number:", result)
# Out:
# enter first number:211
# enter second number:25
# greater number: 211.0

# %%
def factorial(n):
  fact=1
  for i in range (1,n+1):
    fact=fact*i
  return fact
n= int(input("enter a number:"))
if n<0:
  print("factorial is not defined for negative number:")
else:
  print("factorial", factorial(n))
# Out:
# enter a number:6
# factorial 720

# %%
def cel_to_fah(c):
  return (c*9/5)+32
cel=float(input("enter temp in cel"))
fah= cel_to_fah(cel)
print("temp in fahrenheit:",fah)
# Out:
# enter temp in cel125
# temp in fahrenheit: 257.0
